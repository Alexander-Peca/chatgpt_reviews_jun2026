# %%
# smoke test

import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 3.0.3
# 2.4.6

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\alexa\anaconda3\envs\cleaning_phase1\python.exe
