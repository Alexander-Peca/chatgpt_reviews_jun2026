# %%
# Data Ingestion, Understanding, first cleaning ideas

# %%
from pathlib import Path
import sys

# Bootstrap: make project package importable from notebook
NOTEBOOK_PROJECT_ROOT = Path.cwd().parent
SRC_DIR = NOTEBOOK_PROJECT_ROOT / "03_src"

if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

# Imports from project package
from chatgpt_reviews.paths import PROJECT_ROOT, DATA_DIR, RAW_DIR
from chatgpt_reviews.project_io import (
    read_csv_from_raw,
    write_csv_to_processed,
    read_csv_from_processed,
)

# Dataset accessed and saved on June 20 2026
df = read_csv_from_raw("chatgpt_reviews.csv")

# %%
# Data overview using data_overview module

from chatgpt_reviews.data_overview import data_overview

overview = data_overview(df)
# Out:
# Shape: 1,089,749 rows × 8 columns
#
# Top 3 rows (quick peek):
#                                reviewId          userName  \
# 0  d864ac78-952a-42a3-b555-aa0e7b7127e0   Mohammad Shamim
# 1  026cd749-29e3-4956-9a97-a6241c81b95c  Ganesh Pathukula
# 2  d2d65308-2060-45d5-8cd5-f1fd4902814c  Gorle Chandrarao
#
#                                    content  score  thumbsUpCount  \
# 0  this app is very helpful. every person.      5              0
# 1                 Note a clear phot photos      3              0
# 2                                   exlent      4              0
#
#   reviewCreatedVersion                   at  appVersion
# 0           1.2026.160  2026-06-19 09:13:05  1.2026.160
# 1           1.2026.160  2026-06-19 09:12:45  1.2026.160
# 2           1.2026.160  2026-06-19 09:12:45  1.2026.160
# Dtypes (sorted by column name):
# appVersion                str
# at                        str
# content                   str
# reviewCreatedVersion      str
# ...

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['reviewId', 'userName', 'content', 'score', 'thumbsUpCount',
#        'reviewCreatedVersion', 'at', 'appVersion'],
#       dtype='str')>

# %%
display(df.head())
display(df.tail())
# Out:
#                                reviewId          userName  \
# 0  d864ac78-952a-42a3-b555-aa0e7b7127e0   Mohammad Shamim
# 1  026cd749-29e3-4956-9a97-a6241c81b95c  Ganesh Pathukula
# 2  d2d65308-2060-45d5-8cd5-f1fd4902814c  Gorle Chandrarao
# 3  b6428cd3-7d04-49cd-90bd-7cfbb5592268        Rakib Sany
# 4  835c77c7-7a6c-4183-886e-2955f1a1f895      Priti Kumari
#
#                                    content  score  thumbsUpCount  \
# 0  this app is very helpful. every person.      5              0
# 1                 Note a clear phot photos      3              0
# 2                                   exlent      4              0
# 3                                     Good      5              0
# 4                                    nice🤩      5              0
#
#   reviewCreatedVersion                   at  appVersion
# 0           1.2026.160  2026-06-19 09:13:05  1.2026.160
# 1           1.2026.160  2026-06-19 09:12:45  1.2026.160
# ...

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# appVersion              78843
# reviewCreatedVersion    78843
# content                    17
# userName                    2
# score                       0
# reviewId                    0
# thumbsUpCount               0
# at                          0
# dtype: int64
